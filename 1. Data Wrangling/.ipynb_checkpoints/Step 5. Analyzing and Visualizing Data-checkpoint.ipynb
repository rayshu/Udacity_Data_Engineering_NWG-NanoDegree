# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
twitter_archive_master = pd.read_csv('Data/twitter_archive_master.csv')
twitter_archive_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1832  784183165795655680                    NaN                  NaN
# 1833  751132876104687617                    NaN                  NaN
# 1834  744995568523612160                    NaN                  NaN
# 1835  743253157753532416                    NaN                  NaN
# 1836  738537504001953792                    NaN                  NaN
#
#                       timestamp               source  \
# 0     2017-08-01 16:23:56+00:00   Twitter for iPhone
# 1     2017-08-01 00:17:27+00:00   Twitter for iPhone
# 2     2017-07-31 00:18:03+00:00   Twitter for iPhone
# 3     2017-07-30 15:58:51+00:00   Twitter for iPhone
# 4     2017-07-29 16:00:24+00:00   Twitter for iPhone
# ...                         ...                  ...
# 1832  2016-10-07 00:06:50+00:00  Vine - Make a Scene
# 1833  2016-07-07 19:16:47+00:00   Twitter for iPhone
# 1834  2016-06-20 20:49:19+00:00   Twitter for iPhone
# 1835  2016-06-16 01:25:36+00:00   Twitter for iPhone
# 1836  2016-06-03 01:07:16+00:00   Twitter for iPhone
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 1832  This is Reginald. He's one magical puppo. Aero...                  NaN
# 1833  This is Cooper. He's just so damn happy. 10/10...                  NaN
# 1834  This is Abby. She got her face stuck in a glas...                  NaN
# 1835  This is Kilo. He cannot reach the snackum. Nif...                  NaN
# 1836  This is Bayley. She fell asleep trying to esca...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 1832                       NaN                        NaN
# 1833                       NaN                        NaN
# 1834                       NaN                        NaN
# 1835                       NaN                        NaN
# 1836                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 1832                      https://vine.co/v/5ghHLBMMdlV                12
# 1833  https://twitter.com/dog_rates/status/751132876...                10
# 1834  https://twitter.com/dog_rates/status/744995568...                 9
# 1835  https://twitter.com/dog_rates/status/743253157...                10
# 1836  https://twitter.com/dog_rates/status/738537504...                11
#
#       rating_denominator      name dog_stage  \
# 0                     10   Phineas       NaN
# 1                     10     Tilly       NaN
# 2                     10    Archie       NaN
# 3                     10     Darla       NaN
# 4                     10  Franklin       NaN
# ...                  ...       ...       ...
# 1832                  10  Reginald     puppo
# 1833                  10    Cooper     puppo
# 1834                  10      Abby     puppo
# 1835                  10      Kilo     puppo
# 1836                  10    Bayley     puppo
#
#                                               jpg_url  img_num  \
# 0                                                 NaN      NaN
# 1     https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg      1.0
# 2     https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg      1.0
# 3                                                 NaN      NaN
# 4     https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg      2.0
# ...                                               ...      ...
# 1832                                              NaN      NaN
# 1833  https://pbs.twimg.com/media/CmyPXNOW8AEtaJ-.jpg      1.0
# 1834  https://pbs.twimg.com/media/ClbBg4WWEAMjwJu.jpg      1.0
# 1835  https://pbs.twimg.com/media/ClCQzFUUYAA5vAu.jpg      1.0
# 1836                                              NaN      NaN
#
#        dog_type_prediction  prediction_confidence  retweet_count  \
# 0                      NaN                    NaN           8853
# 1                Chihuahua               0.323581           6514
# 2                Chihuahua               0.716012           4328
# 3                      NaN                    NaN           8964
# 4                   basset               0.555712           9774
# ...                    ...                    ...            ...
# 1832                   NaN                    NaN           9374
# 1833    Labrador_retriever               0.929390           1480
# 1834  Old_English_sheepdog               0.427481            716
# 1835              malamute               0.442612           1366
# 1836                   NaN                    NaN           1759
#
#       favorite_count
# 0              39467
# 1              33819
# 2              25461
# 3              42908
# 4              41048
# ...              ...
# 1832           22513
# 1833            5610
# 1834            3277
# 1835            4624
# 1836            5575
#
# [1837 rows x 20 columns]

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    1837 non-null   int64
#  1   in_reply_to_status_id       1 non-null      float64
#  2   in_reply_to_user_id         1 non-null      float64
#  3   timestamp                   1837 non-null   object
#  4   source                      1837 non-null   object
#  5   text                        1837 non-null   object
#  6   retweeted_status_id         139 non-null    float64
#  7   retweeted_status_user_id    139 non-null    float64
#  8   retweeted_status_timestamp  139 non-null    object
#  9   expanded_urls               1837 non-null   object
#  10  rating_numerator            1837 non-null   int64
#  11  rating_denominator          1837 non-null   int64
#  12  name                        1710 non-null   object
#  13  dog_stage                   226 non-null    object
#  14  jpg_url                     1061 non-null   object
#  15  img_num                     1061 non-null   float64
#  16  dog_type_prediction         1061 non-null   object
#  17  prediction_confidence       1061 non-null   float64
#  18  retweet_count               1837 non-null   int64
#  19  favorite_count              1837 non-null   int64
# dtypes: float64(6), int64(5), object(9)
# memory usage: 287.2+ KB

# %%
twitter_archive_master.tweet_id = twitter_archive_master.tweet_id.astype(str)
twitter_archive_master.in_reply_to_status_id = twitter_archive_master.in_reply_to_status_id.astype(str)
twitter_archive_master.in_reply_to_user_id  = twitter_archive_master.in_reply_to_user_id.astype(str)
twitter_archive_master.retweeted_status_id = twitter_archive_master.retweeted_status_id.astype(str)
twitter_archive_master.retweeted_status_user_id  = twitter_archive_master.retweeted_status_user_id.astype(str)
twitter_archive_master.timestamp=pd.to_datetime(twitter_archive_master.timestamp)
twitter_archive_master.retweeted_status_timestamp=pd.to_datetime(twitter_archive_master.retweeted_status_timestamp)
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    1837 non-null   object
#  1   in_reply_to_status_id       1837 non-null   object
#  2   in_reply_to_user_id         1837 non-null   object
#  3   timestamp                   1837 non-null   datetime64[ns, UTC]
#  4   source                      1837 non-null   object
#  5   text                        1837 non-null   object
#  6   retweeted_status_id         1837 non-null   object
#  7   retweeted_status_user_id    1837 non-null   object
#  8   retweeted_status_timestamp  139 non-null    datetime64[ns, UTC]
#  9   expanded_urls               1837 non-null   object
#  10  rating_numerator            1837 non-null   int64
#  11  rating_denominator          1837 non-null   int64
#  12  name                        1710 non-null   object
#  13  dog_stage                   226 non-null    object
#  14  jpg_url                     1061 non-null   object
#  15  img_num                     1061 non-null   float64
#  16  dog_type_prediction         1061 non-null   object
#  17  prediction_confidence       1061 non-null   float64
#  18  retweet_count               1837 non-null   int64
#  19  favorite_count              1837 non-null   int64
# dtypes: datetime64[ns, UTC](2), float64(2), int64(4), object(12)
# memory usage: 287.2+ KB

# %% [markdown]
# ## Insights

# %% [markdown]
# ### 1. Tweet Sources: More than 95% of the users are using twitter for iphone

# %%
twitter_archive_master.source.value_counts().plot(kind = 'bar')

# %%
twitter_archive_master.source.value_counts()['Twitter for iPhone']/twitter_archive_master.source.count()
# Out:
# 0.9542732716385411

# %% [markdown]
# ### 2. Dog stage: 65% of the tweets are about dogs in pupper stage

# %%
explode = (0.2, 0.1, 0.1, 0.1) 
twitter_archive_master.dog_stage.value_counts().plot(kind = 'pie', explode=explode)

# %%
twitter_archive_master.dog_stage.value_counts()['pupper']/twitter_archive_master.dog_stage.count()
# Out:
# 0.6548672566371682

# %% [markdown]
# ### 3. Dog Types: More than 25% of the tweets are abot Top 5 most popular dogs combined

# %%
labels = np.full(len(twitter_archive_master.dog_type_prediction.value_counts()), "", dtype=object)
labels[0]='golden_retriever'
labels[1]='Pembroke'
labels[2]='Labrador_retriever'
labels[3]='Chihuahua'
labels[4]='pug'
twitter_archive_master.dog_type_prediction.value_counts().plot(kind = 'pie', labels=labels)

# %%
((twitter_archive_master.dog_type_prediction.value_counts()['golden_retriever']+
 twitter_archive_master.dog_type_prediction.value_counts()['Pembroke']+
 twitter_archive_master.dog_type_prediction.value_counts()['Labrador_retriever']+
 twitter_archive_master.dog_type_prediction.value_counts()['Chihuahua']+
 twitter_archive_master.dog_type_prediction.value_counts()['pug'])
 / twitter_archive_master.dog_type_prediction.count())
# Out:
# 0.2846371347785108

# %% [markdown]
# ## Visualization

# %%
plt.scatter(twitter_archive_master.retweet_count,twitter_archive_master.favorite_count)
plt.xlabel('Retweet Count')
plt.ylabel('Favorite Count')
# Out:
# Text(0, 0.5, 'Favorite Count')

# %%
plt.scatter(twitter_archive_master.timestamp, twitter_archive_master.retweet_count, label='Retweets')
plt.scatter(twitter_archive_master.timestamp, twitter_archive_master.favorite_count, label='Favorites', alpha=0.2)
plt.xticks(rotation = 45)
# Out:
# (array([735903., 735964., 736024., 736085., 736146., 736208., 736269.,
#         736330., 736389., 736450., 736511., 736573.]),
#  <a list of 12 Text major ticklabel objects>)
